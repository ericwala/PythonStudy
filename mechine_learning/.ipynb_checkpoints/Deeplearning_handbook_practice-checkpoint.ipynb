# %%
import numpy as np
x = np.array([[1,2],[3,4],[5,6]])
x[0]

x = x.flatten()
print(x)
x[np.array([0,2,4])]
x>4
# Out:
# [1 2 3 4 5 6]
# array([False, False, False, False,  True,  True])

# %%
# matplotlib practice
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0,6,0.1)#從0~6以0.1為單位產生資料
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0,6,0.1)

y1 = np.sin(x)
y2 = np.cos(x)

# 繪製圖表

plt.plot(x, y1, label="sin")
plt.plot(x, y2, linestyle ="--", label="cos" )
plt.xlabel("x")
plt.ylabel("y")
plt.title("sin&cos")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
img = imread("C:/Users/a2823/Desktop/deep_learning_practice_code/dataset/lena.png")
plt.imshow(img)
plt.show()

# %%
# 及閘，反及閘，或閘
a = float(input("w1:"))
b = float(input("w2:"))
c = float(input("theta:"))
def AND(x1, x2):
    w1, w2, theta = a, b, c
    
    tmp = x1*w1 + x2*w2
    if tmp <= theta:
        return 0
    else:
        return 1
print(AND(0,0))
print(AND(0,1))
print(AND(1,0))
print(AND(1,1))
# Out:
# w1:1
# w2:2
# theta:1
# 0
# 1
# 0
# 1

# %%
# 偏權質與權重
import numpy as np

w1 = float(input("w1:"))
w2 = float(input("w2:"))
theta = float(input("theta:"))
def AND(x1, x2):
    x = np.array([x1, x2])
    w = np.array([w1, w2])
    
    b = theta
    tmp = np.sum(w*x) + b
    
    if tmp <= 0:
        return 0
    else:
        return 1
print(AND(0,0))
print(AND(0,1))
print(AND(1,0))
print(AND(1,1))
# Out:
# w1:1
# w2:2
# theta:1
# 1
# 1
# 1
# 1

# %%
# 製作互斥及閘
import numpy as np
def AND(x1, x2):#及閘
    x = np.array([x1, x2])
    w = np.array([0.5,0.5])
    b = -0.7
    tmp = np.sum(w*x) + b
    if tmp <= 0:
        return 0
    else:
        return 1
    
def NAND(x1, x2):#反及閘
    x = np.array([x1,x2])
    w = np.array([-0.5,-0.5])
    b = 0.7
    tmp = np.sum(w*x) + b

    if tmp <= 0:
        return 0
    else:
        return 1

def OR(x1, x2):#或閘
    x = np.array([x1,x2])
    w = np.array([0.5,0.5])
    b = -0.2
    tmp = np.sum(w*x) + b
    if tmp <= 0:
        return 0
    else:
        return 1
def XOR(x1,x2):#互斥及閘
    s1 = NAND(x1,x2)
    s2 = OR(x1,x2)
    y = AND(s1,s2)
    return y
print(XOR(0,0))
print(XOR(0,1))
print(XOR(1,0))
print(XOR(1,1))
# Out:
# 0
# 1
# 1
# 0

# %%
# 階梯畫函數圖表
import numpy as np
import matplotlib.pylab as plt
def step_function(x):
    return np.array(x>0, dtype=np.int)
x = np.arange(-5.0, 5.0, 0.1)
y1 = step_function(x)

# sigmoid函數圖表

x = np.arange(-5.0, 5.0, 0.1)
y2 = sigmoid(x)
plt.plot(x, y1, label="step function")
plt.plot(x, y2, linestyle="--", label ="sigmoid")
plt.ylim(-0.1,1.1)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-a00c46c32f17> in <module>
#      10
#      11 x = np.arange(-5.0, 5.0, 0.1)
# ---> 12 y2 = sigmoid(x)
#      13 plt.plot(x, y1, label="step function")
#      14 plt.plot(x, y2, linestyle="--", label ="sigmoid")
#
# NameError: name 'sigmoid' is not defined

# %%
import numpy as np
def sigmoid(x):
    return 1 / (1 + np.exp(-x))
# 第一層
a = np.array([[1,2],[3,4]])
a.shape
b = np.array([[5,6],[7,8]])
np.dot(a,b)

x = np.array([1.0, 0.5])
w1 = np.array([[0.1, 0.3, 0.5], [0.2, 0.4, 0.6]])
b1 = np.array([0.1, 0.2, 0.3])
print(w1.shape)
print(x.shape)
print(b1.shape)
a1 = np.dot(x,w1) + b1
z1 = sigmoid(a1)
print(a1)
print(z1)
# 第二層
w2 = np.array([[0.1, 0.4], [0.2, 0.5], [0.3, 0.6]])
b2 = np.array([0.1, 0.2])
print(z1.shape)
print(w2.shape)
print(b2.shape)
a2 = np.dot(z1,w2) + b2
z2 = sigmoid(a2)
print(a2)
# 第三層(輸出)
def identity_function(x):
    return x
w3 = np.array([[0.1, 0.3], [0.2, 0.4]])
b3 = np.array([0.1, 0.2])
a3 = np.dot(z2, w3) + b3
y = identity_function(a3)
# Out:
# (2, 3)
# (2,)
# (3,)
# [0.3 0.7 1.1]
# [0.57444252 0.66818777 0.75026011]
# (3,)
# (3, 2)
# (2,)
# [0.51615984 1.21402696]

# %%
# 定義softmax函數
import numpy as np

def softmax(a):
    c = np.max(a)
    exp_a = np.exp(a - c)#防溢位
    sum_exp_a = np.sum(exp_a)
    y = exp_a / sum_exp_a
    return y
a = np.array([1010, 1000, 990])

a = a-c
# 計算神經網路輸出
a = np.array([0.3, 2.9, 4.0])
y = softmax(a)
print(y)
print(np.sum(y))#加總為1,可當機率考慮
# Out:
# [0.01821127 0.24519181 0.73659691]
# 1.0

# %%
# MNIST資料集
  # 为了导入父目录的文件而进行的设定

import numpy as np
from dataset.mnist import load_mnist
from PIL import Image
def img_show(img):
    pil_img = Image.fromarray(np.uint8(img))
    pil_img.show()
(x_train, y_train), (x_test, y_test) = load_mnist(flatten=True, normalize=False )
img = x_train[0]
label = y_train[0]
print(label)
print(img.shape)
img = img.reshape(28,28)
print(img.shape)
img_show(img)
print(x_train.shape)
# Out:
# 5
# (784,)
# (28, 28)
# (60000, 784)

# %%
import sys, os
import numpy as np
import pickle
from dataset.mnist import load_mnist
from common.functions import sigmoid, softmax
def get_data():
    (x_train, y_train), (x_test, y_test) = load_mnist(normalize=True, flatten=True, one_hot_label=False)
    return x_test, y_test
def init_network():
    with open("sample_weight.pkl", "rb") as f:
        network = pickle.load(f)
    return network
def predict(network, x):
    w1, w2, w3 = network["W1"], network["W2"], network["W3"]
    b1, b2, b3 = network["b1"], network["b2"], network["b3"]
    
    a1 = np.dot(x,w1) + b1
    z1 = sigmoid(a1)
    a2 = np.dot(z1,w2) + b2
    z2 = sigmoid(a2)
    a3 = np.dot(z2,w3) + b3
    y = softmax(a3)
    return y

x, y = get_data()
network = init_network()

accuracy_cnt = 0
for i in range(len(x)):
    b = predict(network, x[i])
    p = np.argmax(b)#取得機率最高元素索引值
    
    if p == y[i]:
        accuracy_cnt += 1
        
print("accuracy:", str(float(accuracy_cnt) / len(x)))
# Out:
# accuracy: 0.9352

# %%
#批次處理

x, t = get_data()
network = init_network()

batch_size = 100
accuracy_cnt = 0
for i in range(0,len(x),batch_size):
    x_batch = x[i:i+batch_size]
    y_batch = predict(network, x_batch)
    p = np.argmax(y_batch, axis=1)
    accuracy_cnt += np.sum(p == t[i:i+batch_size])
print("accuracy:", str(float(accuracy_cnt) / len(x)))
# Out:
# accuracy: 0.9352

# %%
a = [3, 1, 2, 4, 6, 1]
maxindex = 0
i = 0
for tmp in a:
    if tmp > a[maxindex]:
        maxindex = i
    i += 1
print(maxindex)
# Out:
# 4
